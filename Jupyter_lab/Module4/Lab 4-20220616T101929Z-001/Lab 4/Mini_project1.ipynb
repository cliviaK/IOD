# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_info_csv = r'D:\IOD\Mini Project 1\Airbnb Data\Listings_data_dictionary.csv'
data_info = pd.read_csv(data_csv)
data_info
# Out:
#                           Field  \
# 0                    listing_id
# 1                          name
# 2                       host_id
# 3                    host_since
# 4                 host_location
# 5            host_response_time
# 6            host_response_rate
# 7          host_acceptance_rate
# 8             host_is_superhost
# 9     host_total_listings_count
# 10         host_has_profile_pic
# 11       host_identity_verified
# 12                neighbourhood
# 13                     district
# 14                         city
# 15                     latitude
# 16                    longitude
# 17                property_type
# 18                    room_type
# 19                 accommodates
# 20                     bedrooms
# 21                    amenities
# 22                        price
# 23               minimum_nights
# 24               maximum_nights
# 25         review_scores_rating
# 26       review_scores_accuracy
# 27    review_scores_cleanliness
# ...

# %%
data_csv = r'D:\IOD\Mini Project 1\Airbnb Data\Listings.csv'
data = pd.read_csv(data_csv)
data
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       1 data_csv = r'D:\IOD\Mini Project 1\Airbnb Data\Listings.csv'
# ----> 2 data = pd.read_csv(data_csv)
#       3 data
#
# File ~\Anaconda3-2019.10\envs\IOD\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
